# %%
# Importing the necessry Libraries
import pandas as pd
import dtale 

# Loading the Data

file_path = '/Volumes/T7/project_dal/sampled_dataset.csv'
data = pd.read_csv(file_path)


# Using this you can check all of the dataset Histograms or any kind of desciption in the data
dtale.show(data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://localhost:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Display the first few rows of the dataset to understand its structure
data.head(), data.info(), data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16036 entries, 0 to 16035
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     16036 non-null  int64
#  1   CRASH_RECORD_ID                16036 non-null  object
#  2   CRASH_DATE_EST_I               1195 non-null   object
#  3   CRASH_DATE                     16036 non-null  object
#  4   POSTED_SPEED_LIMIT             16036 non-null  int64
#  5   TRAFFIC_CONTROL_DEVICE         16036 non-null  object
#  6   DEVICE_CONDITION               16036 non-null  object
#  7   WEATHER_CONDITION              16036 non-null  object
#  8   LIGHTING_CONDITION             16036 non-null  object
#  9   FIRST_CRASH_TYPE               16036 non-null  object
#  10  TRAFFICWAY_TYPE                16036 non-null  object
#  11  LANE_CNT                       3930 non-null   float64
# ...

# %%
# Convert CRASH_DATE to datetime
data['CRASH_DATE'] = pd.to_datetime(data['CRASH_DATE'])
# Extract components from CRASH_DATE
data['YEAR'] = data['CRASH_DATE'].dt.year
# the updated DataFrame to confirm changes
data['YEAR']
# Out:
# 0        2023
# 1        2021
# 2        2021
# 3        2020
# 4        2015
#          ...
# 16031    2020
# 16032    2021
# 16033    2020
# 16034    2017
# 16035    2017
# Name: YEAR, Length: 16036, dtype: int32

# %%
# Generate descriptive statistics for numerical features
numerical_descriptive_stats = data.describe()

# Generate a summary for categorical features
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
categorical_descriptive_stats = data[categorical_columns].describe()

numerical_descriptive_stats, categorical_descriptive_stats
# Out:
# (          Unnamed: 0                     CRASH_DATE  POSTED_SPEED_LIMIT  \
#  count   16036.000000                          16036        16036.000000
#  mean   400228.552320  2020-05-06 12:15:44.378897152           28.394674
#  min        11.000000            2015-07-28 09:11:00            0.000000
#  25%    200686.750000            2018-07-18 15:11:15           30.000000
#  50%    400499.000000            2020-05-01 12:46:00           30.000000
#  75%    596290.000000            2022-04-13 19:28:45           30.000000
#  max    801779.000000            2024-01-28 23:21:00           55.000000
#  std    230852.731874                            NaN            6.155825
#
#            LANE_CNT     STREET_NO  BEAT_OF_OCCURRENCE     NUM_UNITS  \
#  count  3930.000000  16036.000000        16036.000000  16036.000000
#  mean      2.597201   3710.585370         1257.902781      2.034111
#  min       0.000000      1.000000          111.000000      1.000000
# ...

# %%
import seaborn as sns
import numpy as np

# Compute the correlation matrix again for numerical variables
correlation_matrix = data.select_dtypes(include=[np.number]).corr()

sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
dtale.show(data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://localhost:40000/dtale/iframe/6"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
